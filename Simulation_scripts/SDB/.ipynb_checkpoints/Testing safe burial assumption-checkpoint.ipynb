# %%
import scipy as sp
import numpy as np
from scipy import stats


def define_distributions():
    
    clinical_x = np.linspace(0, 40, 40)

    incshape = (8.5/7.6)**2
    incscale = (7.6**2)/8.5
    inccdf = sp.stats.gamma.cdf(clinical_x, incshape, loc = 0, scale = incscale)

    death_shape = (8.6/6.9)**2
    death_scale = (6.9**2)/8.6
    death_cdf = sp.stats.gamma.cdf(clinical_x, death_shape, loc = 0, scale = death_scale)

    recovery_shape = (15.2/6.2)**2
    recovery_scale = (6.2**2)/15.2
    recovery_cdf = sp.stats.gamma.cdf(clinical_x, recovery_shape, loc = 0, scale = recovery_scale)
    
    
    return inccdf, death_cdf, recovery_cdf

def get_cdf(dim):

    x = np.linspace(0,dim, dim) #This is where difference between living/dead comes in
    mu = 3.1
    sigma = 2.5

    a = shape = (mu/sigma)**2
    scale = (sigma**2)/mu

    cdf = sp.stats.gamma.cdf(x,a,loc=0,scale=scale)

    return cdf

# %% [markdown]
# ## Currently we have up to seven days of infectivity post-mortem from Prescott et al 2015
#
# A few options:
#
#    - Assume 100% SDB from first wave of cases, so how many cases averted in best case scenario
#    - Introduce SDB in waves - either in time or in effectiveness
#
#    - Try and get a measure of how much SDB there really was and when. Could therefore do some nice matching to reality things?

# %%
import run_model
# Out:
# Successfully importing modules
# Defining parameters
# Importing dictionaries
# Running infection model0 runs completed
#
# initialising individual
# initialising individual
# absolute_day is 1
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 5
# initialising individual
# absolute_day is 10
# initialising individual
# initialising individual
# absolute_day is 8
# initialising individual
# absolute_day is 14
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 13
# initialising individual
# absolute_day is 14
# initialising individual
# absolute_day is 22
# initialising individual
# absolute_day is 12
# initialising individual
# absolute_day is 6
# initialising individual
# absolute_day is 11
# initialising individual
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 14
# initialising individual
# absolute_day is 23
# initialising individual
# initialising individual
# absolute_day is 11
# initialising individual
# initialising individual
# absolute_day is 23
# initialising individual
# absolute_day is 14
# initialising individual
# initialising individual
# absolute_day is 35
# initialising individual
# initialising individual
# absolute_day is 29
# initialising individual
# absolute_day is 30
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 16
# initialising individual
# absolute_day is 25
# initialising individual
# initialising individual
# absolute_day is 16
# initialising individual
# absolute_day is 23
# initialising individual
# absolute_day is 23
# initialising individual
# absolute_day is 28
# initialising individual
# initialising individual
# absolute_day is 36
# initialising individual
# initialising individual
# absolute_day is 31
# initialising individual
# initialising individual
# absolute_day is 31
# initialising individual
# absolute_day is 24
# initialising individual
# initialising individual
# absolute_day is 47
# initialising individual
# initialising individual
# absolute_day is 33
# initialising individual
# initialising individual
# absolute_day is 41
# initialising individual
# absolute_day is 40
# initialising individual
# initialising individual
# absolute_day is 33
# initialising individual
# absolute_day is 35
# initialising individual
# initialising individual
# absolute_day is 36
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 43
# initialising individual
# initialising individual
# absolute_day is 40
# initialising individual
# initialising individual
# absolute_day is 37
# initialising individual
# absolute_day is 41
# initialising individual
# absolute_day is 42
# initialising individual
# absolute_day is 44
# initialising individual
# absolute_day is 55
# initialising individual
# absolute_day is 58
# initialising individual
# initialising individual
# absolute_day is 47
# initialising individual
# absolute_day is 65
# initialising individual
# absolute_day is 48
# initialising individual
# initialising individual
# absolute_day is 40
# initialising individual
# absolute_day is 43
# initialising individual
# initialising individual
# absolute_day is 48
# initialising individual
# initialising individual
# absolute_day is 46
# initialising individual
# absolute_day is 45
# initialising individual
# initialising individual
# absolute_day is 54
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 52
# initialising individual
# absolute_day is 56
# initialising individual
# absolute_day is 48
# initialising individual
# absolute_day is 48
# initialising individual
# absolute_day is 53
# initialising individual
# absolute_day is 68
# initialising individual
# absolute_day is 51
# initialising individual
# absolute_day is 58
# initialising individual
# absolute_day is 60
# initialising individual
# initialising individual
# absolute_day is 54
# initialising individual
# absolute_day is 55
# initialising individual
# absolute_day is 53
# initialising individual
# absolute_day is 51
# initialising individual
# absolute_day is 51
# initialising individual
# initialising individual
# absolute_day is 53
# initialising individual
# absolute_day is 68
# initialising individual
# absolute_day is 60
# initialising individual
# absolute_day is 64
# initialising individual
# absolute_day is 58
# initialising individual
# initialising individual
# absolute_day is 67
# initialising individual
# absolute_day is 67
# initialising individual
# initialising individual
# absolute_day is 61
# initialising individual
# initialising individual
# absolute_day is 66
# initialising individual
# absolute_day is 75
# initialising individual
# absolute_day is 71
# initialising individual
# absolute_day is 83
# initialising individual
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 84
# initialising individual
# absolute_day is 82
# initialising individual
# initialising individual
# absolute_day is 91
# initialising individual
# absolute_day is 111
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 103
# initialising individual
# absolute_day is 101
# initialising individual
# absolute_day is 96
# initialising individual
# absolute_day is 95
# initialising individual
# absolute_day is 103
# initialising individual
# initialising individual
# absolute_day is 100
# initialising individual
# absolute_day is 104
# initialising individual
# absolute_day is 106
# initialising individual
# absolute_day is 105
# initialising individual
# absolute_day is 108
# initialising individual
# absolute_day is 122
# initialising individual
# initialising individual
# absolute_day is 124
# initialising individual
# absolute_day is 106
# initialising individual
# absolute_day is 113
# initialising individual
# absolute_day is 114
# initialising individual
# absolute_day is 130
# initialising individual
# absolute_day is 127
# initialising individual
# initialising individual
# absolute_day is 110
# initialising individual
# initialising individual
# absolute_day is 113
# initialising individual
# absolute_day is 120
# initialising individual
# absolute_day is 113
# initialising individual
# initialising individual
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 113
# initialising individual
# absolute_day is 117
# initialising individual
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 117
# initialising individual
# absolute_day is 116
# initialising individual
# absolute_day is 118
# initialising individual
# absolute_day is 115
# initialising individual
# initialising individual
# absolute_day is 117
# initialising individual
# initialising individual
# absolute_day is 123
# initialising individual
# absolute_day is 117
# initialising individual
# absolute_day is 124
# initialising individual
# initialising individual
# initialising individual
# absolute_day is 134
# initialising individual
# absolute_day is 118
# initialising individual
# initialising individual
# absolute_day is 118
# initialising individual
# absolute_day is 122
# initialising individual
# absolute_day is 131
# initialising individual
# initialising individual
# absolute_day is 126
# initialising individual
# absolute_day is 141
# initialising individual
# absolute_day is 122
# initialising individual
# initialising individual
# absolute_day is 137
# initialising individual
# absolute_day is 137
# initialising individual
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-621feb9428b3> in <module>
# ----> 1 import run_model
#       2
#
# ~/Documents/GitHub/ABSynth/Simulation_scripts/SDB/run_model.py in <module>
#     240 print("Running infection model")
#     241
# --> 242 pool.map(run_model,(iteration_number_outside,))
#     243
#     244 R0_output.close()
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in mapstar(args)
#      42
#      43 def mapstar(args):
# ---> 44     return list(map(*args))
#      45
#      46 def starmapstar(args):
#
# ~/Documents/GitHub/ABSynth/Simulation_scripts/SDB/run_model.py in run_model(iteration_number)
#     121                 newick_string = result[0]
#     122                 skyline = result[1]
# --> 123                 tree = result[2]
#     124                 lineages_through_time = result[5]
#     125
#
# IndexError: tuple index out of range
