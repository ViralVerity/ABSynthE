# %%
# !kernprof -l -v running_tree_sim.py
# Out:
# Wrote profile results to running_tree_sim.py.lprof
# Timer unit: 1e-06 s
#
# Total time: 0.038907 s
# File: /Users/s1743989/Documents/GitHub/ABSynth/Optimisation/Tree_simulator_for_op.py
# Function: sampling at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      8                                           @profile
#      9                                           def sampling(trans_dict, sampled_percentage, epidemic_len):
#     10                                               """Get who is sampled, inputs are list of individual ids and the sampled percentage"""
#     11         1          1.0      1.0      0.0      not_enough_cases = False
#     12         1          1.0      1.0      0.0      week_bins = []
#     13         1          2.0      2.0      0.0      weeks_cases = defaultdict(list)
#     14         1         24.0     24.0      0.1      those_sampled = set()
#     15
# ...

# %%
# !kernprof -l -v running_tree_sim.py
# Out:
# Wrote profile results to running_tree_sim.py.lprof
# Timer unit: 1e-06 s
#
# Total time: 0.005492 s
# File: /Users/s1743989/Documents/GitHub/ABSynth/Optimisation/Tree_simulator_for_op.py
# Function: sampling at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      8                                           @profile
#      9                                           def sampling(trans_dict, sampled_percentage, epidemic_len):
#     10                                               """Get who is sampled, inputs are list of individual ids and the sampled percentage"""
#     11         1          1.0      1.0      0.0      not_enough_cases = False
#     12         1          2.0      2.0      0.0      week_bins = []
#     13         1          2.0      2.0      0.0      weeks_cases = defaultdict(list)
#     14         1         24.0     24.0      0.4      those_sampled = set()
#     15
# ...
